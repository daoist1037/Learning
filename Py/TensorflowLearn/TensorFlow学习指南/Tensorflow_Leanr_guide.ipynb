# %% [markdown]
# ## 2.2 Hello World

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.1.0

# %%
import tensorflow as tf 
h = tf.constant("Hello")
w = tf.constant("World")
hw = h + w 
print(hw)
# Out:
# tf.Tensor(b'HelloWorld', shape=(), dtype=string)

# %% [markdown]
# ## 3.1 实例1

# %%
import tensorflow as tf 
import numpy as np 
import matplotlib.pyplot as plt 

train_x = np.linspace(-1, 1, 100)
train_y = 2 * train_x + np.random.randn(*train_x.shape) * 0.3
print(*train_x.shape)
print(train_x.shape)
# 这里 *train_s.shape 消去了元组的特性
plt.plot(train_x, train_y, 'ro', label='Original data')
plt.legend()
plt.show()

X = tf.placeholder("float")
Y = tf.placeholder("float")

W = tf.Variable(tf.random.normal(shape=1), name='weight')
b = tf.Variable(tf.zeros([1]), name='bias')
z = tf.multiply(X, W) + b
# Out:
# 100
# (100,)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-b63d80428729> in <module>
#      12 plt.show()
#      13
# ---> 14 X = tf.placeholder("float")
#      15 Y = tf.placeholder("float")
#      16
#
# AttributeError: module 'tensorflow' has no attribute 'placeholder'
